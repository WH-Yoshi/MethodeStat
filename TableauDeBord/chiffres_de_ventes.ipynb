# %%
import pandas as pd
import matplotlib.pyplot as plt

def read_csv(file_path):
    return pd.read_csv(file_path, sep=";")

# %%
chiffres = read_csv("ressources/ChiffresVente.csv")

mois = chiffres["Mois"]
y2009 = chiffres["2009"]
y2010 = chiffres["2010"]
y2011 = chiffres["2011"]

# %%
# TODO: Création du graphique en barres, une barre par mois, groupé en mois, sans légende pour l'axe des x
